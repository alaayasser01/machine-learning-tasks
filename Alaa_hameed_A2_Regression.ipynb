# %% [markdown]
# ## Regression

# %%
# %matplotlib notebook
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


np.random.seed(0)
n = 15
x = np.linspace(0,10,n) + np.random.randn(n)/5
y = np.sin(x)+x/6 + np.random.randn(n)/10


X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=0)


plt.figure()
plt.scatter(X_train, y_train, label='training data')
plt.scatter(X_test, y_test, label='test data')
plt.legend(loc=4);

# %% [markdown]
# ### Question 1.1
# Write a function that fits a polynomial LinearRegression model on the training data X_train for degrees 2, 3, 6, and 9. (Use PolynomialFeatures in sklearn.preprocessing to create the polynomial features and then fit a linear regression model) For each model, find 100 predicted values over the interval x = 0 to 10 (e.g. np.linspace(0,10,100)) and store this in a numpy array. The first row of this array should correspond to the output from the model trained on degree 1, the second row degree 3, the third row degree 6, and the fourth row degree 9.

# %%
def answer_one():
    from sklearn.linear_model import LinearRegression
    from sklearn.preprocessing import PolynomialFeatures

    degree =[2 , 3, 6, 9]
    y_pred = np.zeros((len(degree), 100))
    X_train_reshaped = X_train.reshape(-1, 1)
    for i, degree in enumerate(degree):
        poly_features = PolynomialFeatures(degree=degree)
        X_poly_train = poly_features.fit_transform(X_train_reshaped)

        model = LinearRegression()
        model.fit(X_poly_train, y_train)

        X_pred = np.linspace(0, 10, 100).reshape(-1, 1)
        X_pred_poly = poly_features.transform(X_pred)
        y_pred[i, :] = model.predict(X_pred_poly)

    return y_pred

#answer_one()

# %% [markdown]
# ### Fitted model plot

# %%
def plot_one(degree_predictions):
    import matplotlib.pyplot as plt
    plt.figure(figsize=(10,5))
    plt.plot(X_train, y_train, 'o', label='training data', markersize=10)
    plt.plot(X_test, y_test, 'o', label='test data', markersize=10)
    for i,degree in enumerate([1,3,6,9]):
        plt.plot(np.linspace(0,10,100), degree_predictions[i], alpha=0.8, lw=2, label='degree={}'.format(degree))
    plt.ylim(-1,2.5)
    plt.legend(loc=4)

plot_one(answer_one())

# %% [markdown]
# ### Question 1.2
# Comment on the figure above in 2 lines.
# </br> `A low-degree polynomial (1,3) resulted in a simple model that underfitted the data, while a high-degree polynomial (9) resulted in a complex model that overfitted the data and the 6-degree polynomial was complex enough to fit the training & testing data. `

# %% [markdown]
# ### Quick note on $R^2$-score:
# A constant model that always predicts the expected value of y, disregarding the input features, would get a $R^2$-score of 0.0.
#
# ### Question 2
# Write a function that fits a polynomial LinearRegression model on the training data `X_train` for degrees 2 through 9. For each model compute the $R^2$ regression score on the training data as well as the the test data, and return both of these arrays in a tuple.
#
# *This function should return one tuple of numpy arrays `(r2_train, r2_test)`. Both arrays should have shape `(10,)`*

# %%
def answer_two():
    from sklearn.linear_model import LinearRegression
    from sklearn.preprocessing import PolynomialFeatures
    from sklearn.metrics import r2_score

    r2_train = np.zeros(8)
    r2_test = np.zeros(8)

    for i in range (2,10):
       poly_features = PolynomialFeatures(degree=i)
       X_train_poly = poly_features.fit_transform(X_train.reshape(-1, 1))
       X_test_poly = poly_features.transform(X_test.reshape(-1, 1))

       lin_reg = LinearRegression()
       lin_reg.fit(X_train_poly, y_train)

       r2_train[i-2] = r2_score(y_train, lin_reg.predict(X_train_poly))
       r2_test[i-2] = r2_score(y_test, lin_reg.predict(X_test_poly))

    return (r2_train, r2_test)
answer_two()
# Out:
# (array([0.4510998 , 0.58719954, 0.91941945, 0.97578641, 0.99018233,
#         0.99352509, 0.99637545, 0.99803706]),
#  array([-0.06856984,  0.00533105,  0.73004943,  0.87708301,  0.9214094 ,
#          0.92021504,  0.63247948, -0.64525365]))

# %% [markdown]
# ### Question 3
# Plot $R^2$ scores at degrees from 2 to 9.
#
# Based on the $R^2$ scores (degree levels 2 through 9), what degree level corresponds to a model that is underfitting? What degree level corresponds to a model that is overfitting? What choice of degree level would provide a model with good generalization performance on this dataset?

# %%
import matplotlib.pyplot as plt

r2_train, r2_test = answer_two()
degree = np.linspace(2, 9, 8)
plt.plot(degree ,r2_train ,'o' ,label='r2_train' )
plt.plot(degree ,r2_test ,'o' ,label='r2_test')

plt.legend(loc=5)
plt.show()

# %% [markdown]
# **Comment on Q3:**
# </br>
# Underfitting: `the degree 2 model has the lowest training and test R2 scores, which indicates that it is underfitting the data.`
# </br>
# Overfitting: `the degree 9 model has the highest training R2 score, but the lowest test R2 score (high training accuracy but low test accuracy), which indicates that it is overfitting the data.`
# </br>
# </br>
# `the degree 6 model has the highest test R2 score and a high training R2 score(training and test R2 scores are high and close to each other), indicating that it provides a good balance between complexity and generalization.`

# %% [markdown]
# ### Question 4
#
# Training models on high degree polynomial features can result in overly complex models that overfit, so we often use regularized versions of the model to constrain model complexity, as we saw with Ridge and Lasso linear regression.
#
# For this question, train two models: a non-regularized LinearRegression model (default parameters) and a regularized Lasso Regression model (with parameters `alpha=0.01`, `max_iter=10000`) both on polynomial features of degree 12. Return the $R^2$ score for both the LinearRegression and Lasso model's test sets.
#
# *This function should return one tuple `(LinearRegression_R2_test_score, Lasso_R2_test_score)`*
#
# **Comment on the results**
# <br/>1) `the non-regularized linear regression model has a negative R2 score (-4.31), which means that the model is performing very poorly and is overfitting the training data.`
# <br/> 2) `the Lasso R2 test score (0.84) is much better, indicating that it is a better fit for the data and is not overfitting to the training data.`
# <br/>-> `The regularization parameter in the Lasso model reduced the model complexity and prevented overfitting.`

# %%
def answer_four():
    from sklearn.preprocessing import PolynomialFeatures
    from sklearn.linear_model import Lasso, LinearRegression
    from sklearn.metrics import r2_score

    poly_features = PolynomialFeatures(degree=12)
    X_train_poly = poly_features.fit_transform(X_train.reshape(-1, 1))
    X_test_poly = poly_features.transform(X_test.reshape(-1, 1))

    non_regularized_model = LinearRegression()
    non_regularized_model.fit(X_train_poly, y_train)

    LinearRegression_R2_test_score = non_regularized_model.score(X_test_poly, y_test)

    lasso = Lasso(alpha=0.01, max_iter=10000)
    lasso.fit(X_train_poly, y_train)

    Lasso_R2_test_score = lasso.score(X_test_poly, y_test)
    return (LinearRegression_R2_test_score, Lasso_R2_test_score)
answer_four()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.556e-01, tolerance: 6.895e-04
#   model = cd_fast.enet_coordinate_descent(
# (-4.311996022859516, 0.8406625614750236)

# %% [markdown]
# ### Question 5
# Calculate total mean square error.
# $$
# MSE = E[ (ytrue  - yhat)^2 ]
# $$
#
# Then compare your results with scikit-learn implementation of mean square error.

# %%
def mse(y_true, y_pred):
    error = ((y_true-y_pred)**2).mean()
    return error

def compare_builtin_implemented(y_true, y_pred):
    from sklearn.metrics import mean_squared_error
    return (mean_squared_error(y_true, y_pred) , mse(y_true , y_pred))

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=6)
X_train_poly = poly_features.fit_transform(X_train.reshape(-1, 1))
X_test_poly = poly_features.transform(X_test.reshape(-1, 1))

lin_reg = LinearRegression()
lin_reg.fit(X_train_poly, y_train)
y_pred = lin_reg.predict(X_test_poly)

print(compare_builtin_implemented(y_test , y_pred))
# Out:
# (0.03285356966026055, 0.03285356966026055)

# %% [markdown]
# ### Question 6
# Implement a linear regression class **FROM SCRATCH** that can be used by one of the following three options (according to user's choice):
# 1. Ordinary Linear Regression Class
# 2. Implement Ridge Regression Class
# 3. Implement Lasso Regression Class
#
# - Can use numpy
# - Complete the missing code

# %% [markdown]
# **Help**
#
# The gradient descent algorithm is:
#
# $$\begin{align*}& \text{repeat until convergence:} \; \lbrace \newline \; & \phantom {0000} b := b -  \alpha \frac{\partial J(w,b)}{\partial b} \newline       \; & \phantom {0000} w_k := w_k -  \alpha \frac{\partial J(w,b)}{\partial w_k} \tag{1}  \; &
# \newline & \rbrace\end{align*}$$
#
# where, parameters $w, b$ are both updated simultaniously and where for **LINEAR REGRESSION**
# $$
# \frac{\partial J(w,b)}{\partial b}  = \frac{1}{n} \sum\limits_{i = 0}^{n-1} (f_{w,b}(x^{(i)}) - y^{(i)}) \tag{2}
# $$
# $$
# \frac{\partial J(w,b)}{\partial w_k}  = \frac{1}{n} \sum\limits_{i = 0}^{n-1} (f_{w,b}(x^{(i)}) -y^{(i)})x^{(i)}_k \tag{3}
# $$
#
# *  $f_{w,b}(x^{(i)})$ is the model's prediction, while $y^{(i)}$, is the target value
#
#
# You will implement a function called `update_weights` which calculates $\frac{\partial J(w)}{\partial w_k}$, $\frac{\partial J(w)}{\partial b}$ for each type of regression --> different gradients for each type
#
#
# For example for **Linear Regression**, the `updat_weights` function should:
#
# * Iterate over the training examples, and for each example, compute:
#     * The prediction of the model for that example
#     $$
#     f_{wb}(x^{(i)}) =  \sum_{k=1}^{k=m}w_kx^{(i)} + b
#     $$
#
#     * Loop over features $k$ and calculate the gradient for each parameter $w_k$
#         $$
#         \frac{\partial J(w,b)}{\partial w_k}^{(i)}  =  (f_{w,b}(x^{(i)}) -y^{(i)})x^{(i)}_k
#         $$
#     * Then for $b$ from that example
#         $$
#         \frac{\partial J(w,b)}{\partial b}^{(i)}  =  (f_{w,b}(x^{(i)}) - y^{(i)})
#         $$
#
# * Calculate the total gradient update from all the examples for each parameter $w_k$ and $b$
#     $$
#     \frac{\partial J(w,b)}{\partial b}  = \frac{1}{n} \sum\limits_{i = 0}^{n-1} \frac{\partial J(w,b)}{\partial b}^{(i)}
#     $$
#
#     $$
#     \frac{\partial J(w,b)}{\partial w_k}  = \frac{1}{n} \sum\limits_{i = 0}^{n-1} \frac{\partial J(w,b)}{\partial w_k}^{(i)}
#     $$
#   * Here, $n$ is the number of training examples and $\sum$ is the summation operator
#
# * Then update weights

# %%
import numpy as np

# Linear Regression

class LinearRegression() :

    def __init__( self, learning_rate, iterations, type="linear" , reg_parameter = 0) :
        """
        This function initializes the object instance with arguments learning_rate, number of iterations, and whether to use linear or ridge or lasso
        reg_paramter is lambda for regularized regression"""

        self.learning_rate = learning_rate

        self.iterations = iterations

        self.type = type

        self.lam = reg_parameter

    def fit( self, X, Y ) :
        self.m, self.n = X.shape[1] , X.shape[0]

        # weight initialization, initialize w to random numbers from a uniform distribution over [0,1(
        self.W = np.random.uniform(low=0.0, high=1.0, size= self.m)
        # intialize b to 0

        self.b = 0



        self.X = X


        self.Y = Y

        # gradient descent learning

        for i in range( self.iterations ) :

            self.update_weights()

        return self

    def update_weights( self ) :

        Y_pred = self.predict( self.X )

        # calculate gradients
        if self.type == 'linear':
            dW = (1/self.n) * self.X.T.dot(Y_pred - self.Y)

            db = (1/self.n) * np.sum(Y_pred- self.Y)

        elif self.type == 'ridge':
            dW = (1/self.n) * self.X.T.dot(Y_pred - self.Y) + 2* self.learning_rate * self.W

            db = (1/self.n) * np.sum(Y_pred- self.Y)
        else:
            dW =  (1/self.n) * self.X.T.dot(Y_pred - self.Y) + self.learning_rate * np.sign(self.W)

            db = (1/self.n) * np.sum(Y_pred- self.Y)

        # update weights
        self.W = self.W -  self.learning_rate * dW

        self.b = self.b -  self.learning_rate * db

        # you don't need to return w and b
        return self

    def predict( self, X ) :
        y_pred   = np.dot(X, self.W) + self.b
        return y_pred

# %% [markdown]
# ### Part 2
# Run the following cells to download fmnist dataset which will be used for the rest of the assignment.

# %%
# !pip install openml

# General imports
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openml as oml
from matplotlib import cm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openml
#   Downloading openml-0.13.0-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.1/140.1 KB 4.0 MB/s eta 0:00:00
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Collecting liac-arff>=2.4.0
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting minio
#   Downloading minio-7.1.13-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 KB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.2 in /usr/local/lib/python3.9/dist-packages (from openml) (1.22.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from openml) (2.8.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from openml) (1.4.4)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.9/dist-packages (from openml) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.9/dist-packages (from openml) (1.2.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.9/dist-packages (from openml) (9.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from openml) (2.25.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->openml) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil->openml) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.18->openml) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.18->openml) (1.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from minio->openml) (2022.12.7)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from minio->openml) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->openml) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->openml) (2.10)
# Building wheels for collected packages: liac-arff
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11732 sha256=2d800b1d5d215ce160a6e341f21adf82190ea8763f98fa1827bce67c0f54fe63
#   Stored in directory: /root/.cache/pip/wheels/08/82/8b/5c514221984e88c059b94e36a71d4722e590acaae04deab22e
# Successfully built liac-arff
# Installing collected packages: xmltodict, minio, liac-arff, openml
# Successfully installed liac-arff-2.5.0 minio-7.1.13 openml-0.13.0 xmltodict-0.13.0

# %%
# Download FMINST data. Takes a while the first time.
fmnist = oml.datasets.get_dataset(40996)
X, y, _, _ = fmnist.get_data(target=fmnist.default_target_attribute);
fmnist_classes = {0:"T-shirt/top", 1: "Trouser", 2: "Pullover", 3: "Dress", 4: "Coat", 5: "Sandal",
                  6: "Shirt", 7: "Sneaker", 8: "Bag", 9: "Ankle boot"}

# %%
# Take some random examples, reshape to a 32x32 image and plot
from random import randint
fig, axes = plt.subplots(1, 5,  figsize=(10, 5))
for i in range(5):
    n = randint(0,70000)
    axes[i].imshow(X.values[n].reshape(28, 28), cmap=plt.cm.gray_r)
    axes[i].set_xlabel((fmnist_classes[int(y.values[n])]))
    axes[i].set_xticks(()), axes[i].set_yticks(())
plt.show();

# %% [markdown]
# ### Question 7
# First, we'll try the default Logistic Regression and k-Nearest Neighbors as a point of reference. To see whether our models are overfitting, we also evaluate the training set error. This can be done using cross_validation.
#
# Implement the following `evaluate_learners` function which evaluates each classifier passed into it on the given data, and then returns both the train and test scores of each as a list. You must use `cross_validate` function.

# %%
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# Take a 10% stratified subsample to speed up experimentation
Xs, _, ys, _ = train_test_split(X,y, stratify=y, train_size=0.1, random_state =0)

# %%
def evaluate_learners(classifiers, X, y):
    """ Evaluate each classifier in 'classifiers' with cross-validation on the provided (X, y) data.

    Given a list of scikit-learn classifiers [Classifier1, Classifier2, ..., ClassifierN] return two lists:
     - a list with the scores obtained on the training samples for each classifier,
     - a list with the test scores obtained on the test samples for each classifier.
     The order of scores should match the order in which the classifiers were originally provided. E.g.:
     [Classifier1 train score, ..., ClassifierN train score], [Classifier1 test score, ..., ClassifierN test score]
    """
    test_results =[]
    train_results =[]
    for classifier in classifiers:
      validation =cross_validate(classifier, X, y=y,cv=5 , return_train_score=True)
      test_results.append(validation["test_score"])
      train_results.append(validation["train_score"])

    return (train_results , test_results)
# # Example output:
# train_scores, test_scores = ([[0.92 , 0.924, 0.916, 0.917, 0.921],  # Classifier 1 train score for each of 5 folds.
#                               [0.963, 0.962, 0.953, 0.912, 0.934],  # Classifier 2 train score for each of 5 folds.
#                              [[0.801, 0.811, 0.806, 0.826, 0.804],  # Classifier 1 test score for each of 5 folds.
#                               [0.766, 0.756, 0.773, 0.756, 0.741],  # Classifier 2 test score for each of 5 folds.

# %% [markdown]
# With this small sample of our data we can now train and evaluate the two classifiers.

# %%
classifiers = [LogisticRegression(), KNeighborsClassifier()]
train_scores, test_scores = evaluate_learners(classifiers, Xs, ys)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Print train scores and test scores.

# %%
print(train_scores, test_scores)
# Out:
# [array([0.9125    , 0.92053571, 0.92089286, 0.92089286, 0.91767857]), array([0.86375   , 0.86571429, 0.86321429, 0.86267857, 0.86821429])] [array([0.835     , 0.80071429, 0.82      , 0.81428571, 0.81214286]), array([0.79428571, 0.82285714, 0.79857143, 0.81285714, 0.79928571])]

# %% [markdown]
# ### Regularization
# We will now tune these algorithm's main regularization hyperparameter: the regularization parameter in logistic regression (alpha), and the number of neighbors (n_neighbors) in kNN. We expect the optimum for n_neighbors between 1 and 50. Alpha should be varied on a log scale (i.e. [0.01, 0.1, 1, 10, 100]) and k should be varied uniformly (i.e. [1,2,3,4]).

# %% [markdown]
# ### Question 8
# In the following cells we vary the regularization parameters in the range given above and, for each classifier, we create a line plot that plots both the training and test score for every value of the regularization hyperparameter. Hence, 2 plots are produced, one for each classifier. We use 5-fold cross validation for all scores, but only plot the means.

# %%
from sklearn.model_selection import GridSearchCV

param_c = {'C': np.logspace(-12, 12, num=22)}
param_k = {'n_neighbors': np.geomspace(1, 60, num=12, dtype=int)[1:]}
grids = [param_c, param_k]
grid_searches = [GridSearchCV(clf, grid, n_jobs=-1, cv=3, return_train_score=True).fit(Xs, ys) for clf,grid in zip(classifiers,grids)]
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Generic plot for 1D grid search
# grid_search: the result of the GridSearchCV
# param_name: the name of the parameter that is being varied
def plot_tuning(grid_search, param_name, ax):
    ax.plot(grid_search.param_grid[param_name], grid_search.cv_results_['mean_test_score'], marker = '.', label = 'Test score')
    ax.plot(grid_search.param_grid[param_name], grid_search.cv_results_['mean_train_score'], marker = '.', label = 'Train score')
    ax.set_ylabel('score (ACC)')
    ax.set_xlabel(param_name)
    ax.legend()
    ax.set_xscale('log')
    ax.set_title(grid_search.best_estimator_.__class__.__name__)
    bp, bs = grid_search.best_params_[param_name], grid_search.best_score_
    ax.text(bp,bs,"  C:{:.2E}, ACC:{:.4f}".format(bp,bs))

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
for grid_search, param, ax in zip(grid_searches,['C','n_neighbors'],axes):
    plot_tuning(grid_search, param, ax)

# %% [markdown]
# Interpret the plots. When are the methods underfitting? When are they overfitting? How sensitive are they to the regularization hyperparameter?

# %% [markdown]
# for LogisticRegression: <br/>
# `A smaller value of alpha leads to weaker regularization, which results in a model with more freedom and underfitting occured.`<br/>
# ` A larger value of alpha leads to stronger regularization, which results in a model that overfits the data (but not too much).`
#
# <br/>
# for KNN :
# <br/>
#
# ` When n_neighbors is too small, the classifier is too sensitive to noise and overfit the training data, with poor generalization to new, unseen data. `
# <br/>`When n_neighbors is too large, the classifier underfits the training data. `
#
# <br/>
# <br/>
#
#  `A hyperparameter in between can be good to ballance the generalization and fit the data and can be choosen using cross validation `

# %% [markdown]
# ## Interpreting misclassifications
# We train a logistic regression model on the data to look at the confusion matrix

# %%
# Create a stratified train-test split on a sample
X_train, X_test, y_train, y_test = train_test_split(Xs,ys, stratify=ys, random_state=0)

# %%
# model implementation:
model = LogisticRegression(C=1e-7).fit(X_train,y_train)
y_pred = model.predict(X_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Question 9
# A confusion matrix shows the amount of examples in for each pair of true and predicted classes. Interpret the results. Draw the complete confusion matrix for the true and predicted test data.
#
# ### Interpretion:
# `it is a good classifier as it has high values on the diagonal ( high numbers of true positives and true negatives) and low values in the rest of the matrix (low numbers of false positives and false negatives)`

# %%
labels = np.unique(y_train).tolist()
cm = np.zeros((len(labels) ,len(labels)))
y_true = y_test.to_numpy()

for i in range(len(y_pred)):
  true= labels.index(y_true[i])
  pred = labels.index(y_pred[i])
  cm[true, pred]+=1
# print(cm)
# Out:
# [[147.   2.   2.  12.   0.   0.   9.   0.   3.   0.]
#  [  0. 169.   4.   2.   0.   0.   0.   0.   0.   0.]
#  [  2.   0. 119.   1.  32.   0.  18.   0.   3.   0.]
#  [  8.   0.   1. 155.   5.   0.   6.   0.   0.   0.]
#  [  0.   0.  16.  10. 135.   0.  14.   0.   0.   0.]
#  [  0.   0.   0.   0.   0. 122.   0.  34.   1.  18.]
#  [ 51.   1.  19.   8.  20.   0.  72.   0.   4.   0.]
#  [  0.   0.   0.   0.   0.   3.   0. 157.   1.  14.]
#  [  0.   0.   3.   4.   0.   1.   1.   0. 166.   0.]
#  [  0.   0.   0.   0.   0.   1.   0.  10.   0. 164.]]

# %%
fig, ax = plt.subplots()
im = ax.imshow(cm)
ax.set_xticks(np.arange(10)), ax.set_yticks(np.arange(10))
ax.set_xticklabels(list(fmnist_classes.values()), rotation=45, ha="right")
ax.set_yticklabels(list(fmnist_classes.values()))
ax.set_ylabel('True')
ax.set_xlabel('Predicted')
for i in range(100):
    ax.text(int(i/10),i%10,cm[i%10,int(i/10)], ha="center", va="center", color="w")

# %% [markdown]
# ## Interpreting model parameters
# Finally, we'll take a closer look at the model parameters, i.e. the coefficients of our linear models. Since we are dealing with 28x28 pixel images, we have to learn 784 coefficients. What do these coefficients mean? We'll start by plotting them as 28x28 pixel images.

# %% [markdown]
# ### Question 10
# Train a Logistic Regression model using its tuned hyperparameter from gridsearch used above.
# When in doubt, use `C=1e-7` for LogReg.
# Pass the trained model to the provided plotting function. Interpret the results in detail.
# Why do you get multiple plots per model? What do the features represent in your data.
# Does it seems like the models pay attention to the right features?
# Do you models seem to ignore certain features? Do you observe differences in quality between the different classes?

# %%
# Plots the coefficients of the given model as 28x28 heatmaps.
# The `name` attribute is optional, it is simply a title for the produced figure
def plot_coefficients(model, name=None):
    fig, axes = plt.subplots(1,10,figsize=(20,2))
    fig.suptitle(name if name else model.__class__.__name__)
    for i, ax in enumerate(axes):
        m = ax.imshow(model.coef_[i].reshape(28,28))
        ax.set_xlabel(fmnist_classes[i])
        ax.set_xticks(()), ax.set_yticks(())
    fig.colorbar(m, ax=axes.ravel().tolist())

# %%
##### Call on the function plot_coefficients using your trained model
plot_coefficients(model)

# %% [markdown]
# **Hint** that linear models are typically binary classifiers. They will solve multi-class problems in a one-vs-all approach. Hence, for a 10-class problem, they will build 10 models, each one trained to predict whether an instance is from a specific class or not. This leads to 10 sets of 784 trained coefficients. Above, we plot them as 28x28 matrices, such that each coefficient is plotted at the location of their corresponding pixel value.

# %% [markdown]
# **Answer:**
#
# - `Each plot represents a separate model,to predict whether an instance belongs to a specific class or not.`
# <br/>
# - `The 28x28 matrix for each model represents the contribution of each pixel in the image to the model's prediction.`
# <br/>
# - `The features in the data are pixel values.. Each pixel represents the intensity of the corresponding point in the image.`
# <br/>
# -`The goal is to use these pixel values to classify the image into one of ten classes.`
# <br/>
# - `The model pays attention to important features as the edges of the shape that distinguish a specific class from another have higher intenisty (t-shirt shape is clear) and ignores the features that do not help him in that.`
# <br/>
# - `Differences in quality may be observed depending on the difficulty of classifying each class.. classes that are similar in appearance may be more difficult to distinguish, leading to lower quality predictions for these classes.`

# %% [markdown]
# ### Question 11
# Finally, out of curiosity, let's see the result of underfitting and overfitting on the learned coefficients:
# Repeat the previous exercise, only with logistic regression. In addition to a tuned version, also add a model that overfits a lot and one that underfits a lot.

# %% [markdown]
# In the cell below replace the ####### with your trained models with different alphas.

# %%
plot_coefficients(LogisticRegression(C=1e-10).fit(X_train,y_train),"Underfitting logistic regression")
plot_coefficients(LogisticRegression(C=1e-7).fit(X_train,y_train),"Good fit logistic regression")
plot_coefficients(LogisticRegression(C=1e10).fit(X_train,y_train),"Overfitting logistic regression")
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Interpret and explain the results.
# * **Answer:**
#
# - Underfitting : `The data leared by the model does not include any noise which means that the model will not be able to predict the class of a noisy data correctly (low training and low testing scores)`
# - overfitting : `The model learned all the training data noise , which means that the training score is high but when it is a new (unlearned) enstance it will be difficult to predect it correctly (low testing score)`
# - Good fit: `The model accurately represents the underlying relationships in the data it was trained on, and is also able to generalize to new data as it does not learn the actual noise of the training data. `
